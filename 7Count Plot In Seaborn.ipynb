# %% [markdown]
# **Count Plot in Seaborn**

# %%
# Counte Plot needs only x Parameter

# import seaborn as sns
# import matplotlib.pyplot as plt
# import pandas as pd

# data = sns.load_dataset(" ")
# sns.countplot(x=" ", data=data)
# plt.show()

# Whats the difference between countplot and barplot ?
# Countplot plots the count of the number of records by category.
# BArplot plot a value or metrics for each category(By default barplot plots the mean of variable, by category).

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = sns.load_dataset("tips")
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.countplot(x="sex", data=data,)
plt.show()

# %%
sns.barplot(x="sex", y="size", data=data)
plt.show()

# %%
sns.countplot(x="sex", data=data,)
plt.show()

# %%
sns.countplot(x="sex", data=data, hue="smoker")
plt.show()

# %%
sns.countplot(x="sex", data=data, hue="smoker", palette="bwr")
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.countplot(x="sex", data=data, hue="smoker", color="r")
plt.show()

# %%
sns.countplot(x="sex", data=data, hue="smoker", color="r", saturation=0.1)
plt.show()
# Saturation come upto 0-1
